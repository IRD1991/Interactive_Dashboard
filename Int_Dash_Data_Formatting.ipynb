# %% [markdown]
# ### Import dependencies and data

# %%
import pandas as pd
from datetime import datetime
from functools import reduce

# %%
cpi_df = pd.read_csv('cpi_data.csv')
gdp_df = pd.read_csv('monthly_gdp_data.csv')
mortgages_df = pd.read_csv('mortgage_approvals_data.csv')
interest_df = pd.read_csv('interest_rates_data.csv')
ukhpi_df = pd.read_csv('ukhpi_data.csv')
avg_price_df = pd.read_csv('avg_price_data.csv')

# %% [markdown]
# ### CPI Data - Consumer Price Index

# %%
cpi_df.head()
# Out:
#     v4_0  mmm-yy    Time    uk-only       Geography cpih1dim1aggid  \
# 0  128.0  Aug-23  Aug-23  K02000001  United Kingdom    CP0953_0954
# 1  112.6  Aug-23  Aug-23  K02000001  United Kingdom          CP052
# 2  128.4  Aug-23  Aug-23  K02000001  United Kingdom      CP082_083
# 3   97.3  Aug-23  Aug-23  K02000001  United Kingdom          CP091
# 4  216.5  Aug-23  Aug-23  K02000001  United Kingdom         CP0733
#
#                                            Aggregate
# 0  09.5.3/4 Miscellaneous printed matter, station...
# 1                            05.2 Household textiles
# 2             08.2/3 Telephone and telefax equipment
# 3   09.1 Audio-visual equipment and related products
# 4                  07.3.3 Passenger transport by air

# %%
list(set(cpi_df['Aggregate'].tolist()))
# Out:
# ['09.1.3 Data processing equipment',
#  '09.3 Other recreational items, gardens and pets',
#  '07.3 Transport services',
#  '05.4 Glassware, tableware and household utensils',
#  '02.1.3 Beer',
#  '07.1 Purchase of vehicles',
#  '05.2 Household textiles',
#  '11.1.2 Canteens',
#  '01.1.3 Fish',
#  '03.1.4 Cleaning, repair and hire of clothing',
#  '01.1 Food',
#  '07.3.1 Passenger transport by railway',
#  '11.1.1 Restaurants and cafes',
#  '12.1 Personal care',
#  '07.3.3 Passenger transport by air',
#  '01.1.5 Oils and fats',
#  '07.1.1.1 New motor cars',
#  '12.5.3 Health insurance',
#  '09 Recreation and culture',
#  '04.5 Electricity, gas and other fuels',
#  '11 Restaurants and hotels',
#  '04.4.1 Water supply',
#  'Overall Index',
#  '01 Food and non-alcoholic beverages',
#  '08.1 Postal services',
#  '12.1.2/3 Appliances and products for personal care',
#  '03 Clothing and footwear',
#  '06.1.2/3 Other medical and therapeutic equipment',
#  '01.2.1 Coffee, tea and cocoa',
#  '05.5 Tools and equipment for house and garden',
#  '02.1 Alcoholic beverages',
#  '07.2.1 Spare parts and accessories',
#  '12.4 Social protection',
#  '09.1.2 Photographic, cinematographic and optical equipment',
#  '01.1.2 Meat',
#  '09.1.5 Repair of audio-visual equipment, related products',
#  '09.5 Books, newspapers and stationery',
#  '06.2.2 Dental services',
#  '03.1.3 Other clothing and clothing accessories',
#  '01.2.2 Mineral waters, soft drinks and juices',
#  '01.1.8 Sugar, jam, syrups, chocolate and confectionery',
#  '04.3 Regular maintenance and repair of the dwelling',
#  '09.3.3 Gardens, plants and flowers',
#  '07.2.2 Fuels and lubricants',
#  '08 Communication',
#  '06 Health',
#  '01.1.4 Milk, cheese and eggs',
#  '04.9 Council Tax and rates',
#  '07.3.2/6 Passenger transport by road and other services',
#  '03.1.2 Garments',
#  '12 Miscellaneous goods and services',
#  '04.5.2 Gas',
#  '01.1.9 Food products (nec)',
#  '09.1.4 Recording media',
#  '12.5.2 House contents insurance',
#  '12.1.1 Hairdressing and personal grooming establishments',
#  '05.6.2 Domestic services and household services',
#  '05 Furniture, household equipment and maintenance',
#  '09.6 Package holidays',
#  '07.2 Operation of personal transport equipment',
#  '09.3.2 Equipment for sport and open-air recreation',
#  '04.3.2 Services for maintenance and repair of the dwelling',
#  '05.1.1 Furniture and furnishings',
#  '06.2 Out-patient services',
#  '04.4.3 Sewerage collection',
#  '08.2/3 Telephone and telefax equipment',
#  '02.1.1 Spirits',
#  '04.5.4 Solid fuels',
#  '04.1 Actual rentals for housing',
#  '07.2.3 Maintenance and repairs',
#  '04.5.1 Electricity',
#  '02.2 Tobacco',
#  '12.3.1 Jewellery, clocks and watches',
#  '09.4.2 Cultural services',
#  '07.1.1.2 Second-hand motor cars',
#  '06.3 Hospital services',
#  '01.1.6 Fruit',
#  '05.6 Goods and services for routine maintenance',
#  '05.1.2 Carpets and other floor coverings',
#  '05.1 Furniture, furnishings and carpets',
#  '05.3 Household appliances, fitting and repairs',
#  '07 Transport',
#  '09.1.1 Reception and reproduction of sound and pictures',
#  '09.4.1 Recreational and sporting services',
#  '04.5.3 Liquid fuels',
#  '06.2.1/3 Medical services and paramedical services',
#  '02 Alcoholic beverages and tobacco',
#  '07.3.4 Passenger transport by sea and inland waterway',
#  '05.6.1 Non-durable household goods',
#  '12.3.2 Other personal effects',
#  '09.4 Recreational and cultural services',
#  '04.4 Water supply and miscellaneous services relating to the dwelling',
#  '09.5.1 Books',
#  '02.1.2 Wine',
#  '09.1.5 Repair of audio-visual equipment and related products',
#  '05.3.3 Repair of household appliances',
#  '09.3.1 Games, toys and hobbies',
#  '07.1.2/3 Motocycles and bicycles',
#  '12.5 Insurance',
#  '11.1 Catering services',
#  '07.1.1b Second Hand Cars',
#  '01.1.7 Vegetables including potatoes and tubers',
#  '09.5.2 Newspapers and periodicals',
#  '06.1 Medical products, appliances and equipment',
#  '09.2 Other major durables for recreation and culture',
#  '12.3 Personal effects (nec)',
#  '03.2 Footwear including repairs',
#  '07.1.1 New Cars',
#  '12.5.4 Transport insurance',
#  '07.1.2/3 Motorcycles and bicycles',
#  '04 Housing, water, electricity, gas and other fuels',
#  '01.1.1 Bread and cereals',
#  '09.3.4/5 Pets, related products and services',
#  '09.1 Audio-visual equipment and related products',
#  '07.2.4 Other services',
#  '12.7 Other services (nec)',
#  '05.3.1/2 Major appliances and small electric goods',
#  '06.1.1 Pharmaceutical products',
#  '03.1 Clothing',
#  '11.2 Accommodation services',
#  '09.5.3/4 Miscellaneous printed matter, stationery and drawing materials',
#  '04.3.1 Materials for maintenance and repair of the dwelling',
#  '04.2 Owner Occupiers Housing Costs',
#  '12.6 Financial services (nec)',
#  '10 Education',
#  '01.2 Non-alcoholic beverages']

# %%
overall_cpi_df = cpi_df[cpi_df['Aggregate'].isin(['Overall Index', '04 Housing, water, electricity, gas and other fuels'])]\
        .drop(columns = ['Time', 'uk-only', 'Geography', 'cpih1dim1aggid'])\
        .reset_index(drop=True)
overall_cpi_df.head()
# Out:
#     v4_0  mmm-yy                                          Aggregate
# 0  129.4  Aug-23                                      Overall Index
# 1  127.8  Aug-23  04 Housing, water, electricity, gas and other ...
# 2  104.2  Sep-17  04 Housing, water, electricity, gas and other ...
# 3  104.3  Sep-17                                      Overall Index
# 4   79.3  Jan-06  04 Housing, water, electricity, gas and other ...

# %%
overall_cpi_df['mmm-yy'] = overall_cpi_df['mmm-yy'].apply(lambda x: datetime.strptime(x, '%b-%y').strftime('%d/%m/%Y'))
overall_cpi_df['Aggregate'].mask(overall_cpi_df['Aggregate'] == '04 Housing, water, electricity, gas and other fuels',
                                 'Housing Associated Costs', inplace=True)

# %%
overall_cpi_df = overall_cpi_df.rename(columns={'v4_0': 'cpi', 'mmm-yy': 'Date'})

# %%
overall_cpi_df['Date'] = pd.to_datetime(overall_cpi_df['Date'], format='%d/%m/%Y')

# %%
overall_cpi_df = overall_cpi_df.pivot(index='Date', columns='Aggregate', values='cpi')

# %%
overall_cpi_df.sort_values('Date').head()
# Out:
# Aggregate   Housing Associated Costs  Overall Index
# Date
# 1988-01-01                      38.7           46.9
# 1988-02-01                      38.8           47.0
# 1988-03-01                      39.0           47.2
# 1988-04-01                      39.8           47.8
# 1988-05-01                      40.0           48.0

# %% [markdown]
# ### Monthly GDP Estimate Data

# %%
gdp_df.head()
# Out:
#        v4_0  mmm-yy    Time    uk-only       Geography sic-unofficial  \
# 0   79.3539  Jan-09  Jan-09  K02000001  United Kingdom              F
# 1   93.8681  Jan-09  Jan-09  K02000001  United Kingdom           B--E
# 2   80.5284  Jan-09  Jan-09  K02000001  United Kingdom           G--T
# 3  102.3273  Jan-09  Jan-09  K02000001  United Kingdom              A
# 4   82.3913  Jan-09  Jan-09  K02000001  United Kingdom           A--T
#
#   UnofficialStandardIndustrialClassification
# 0                           F : Construction
# 1                B-E : Production Industries
# 2                    G-T : Index of Services
# 3                            A : Agriculture
# 4                          A-T : Monthly GDP

# %%
monthly_gdp_df = gdp_df[gdp_df['sic-unofficial'] == 'A--T']\
        .drop(columns = ['Time', 'uk-only', 'Geography', 'sic-unofficial'])\
        .reset_index(drop=True)

# %%
monthly_gdp_df['mmm-yy'] = monthly_gdp_df['mmm-yy'].apply(lambda x: datetime.strptime(x, '%b-%y').strftime('%d/%m/%Y'))
monthly_gdp_df['UnofficialStandardIndustrialClassification'] = 'Monthly GDP'

# %%
monthly_gdp_df = monthly_gdp_df.rename(columns={'v4_0': 'gdp',
                                                'mmm-yy': 'Date',
                                                'UnofficialStandardIndustrialClassification': 'GDP'})

# %%
monthly_gdp_df['Date'] = pd.to_datetime(monthly_gdp_df['Date'], format='%d/%m/%Y')

# %%
monthly_gdp_df = monthly_gdp_df.pivot(index='Date', columns='GDP', values='gdp')

# %%
monthly_gdp_df.sort_values('Date').head()
# Out:
# GDP         Monthly GDP
# Date
# 1997-01-01      63.3398
# 1997-02-01      63.9959
# 1997-03-01      64.0355
# 1997-04-01      64.6273
# 1997-05-01      64.1371

# %% [markdown]
# ### Mortgage Approvals Data

# %%
mortgages_df.head()
# Out:
#           DATE  LPMVTVU
# 0  30 Apr 1993    90963
# 1  31 May 1993    91684
# 2  30 Jun 1993   100672
# 3  31 Jul 1993    93576
# 4  31 Aug 1993    83478

# %%
mortgages_df['DATE'] = pd.to_datetime(mortgages_df['DATE'], format='%d %b %Y') + pd.offsets.MonthBegin(1)

# %%
mortgages_df.rename(columns={
    'DATE': 'Date',
    'LPMVTVU': 'Mortgage Approvals'}, inplace=True)

# %%
mortgages_df.set_index('Date', inplace=True)

# %%
mortgages_df.head()
# Out:
#             Mortgage Approvals
# Date
# 1993-05-01               90963
# 1993-06-01               91684
# 1993-07-01              100672
# 1993-08-01               93576
# 1993-09-01               83478

# %% [markdown]
# ### Base Interest Rates Data

# %%
interest_df.head()
# Out:
#           DATE  IUMABEDR
# 0  28 Feb 1990    14.875
# 1  31 Mar 1990    14.875
# 2  30 Apr 1990    14.875
# 3  31 May 1990    14.875
# 4  30 Jun 1990    14.875

# %%
interest_df['DATE'] = pd.to_datetime(interest_df['DATE'], format='%d %b %Y') + pd.offsets.MonthBegin(1)

# %%
interest_df.rename(columns={
    'DATE': 'Date',
    'IUMABEDR': 'Base Interest Rate'}, inplace=True)

# %%
interest_df.set_index('Date', inplace=True)

# %%
interest_df.head()
# Out:
#             Base Interest Rate
# Date
# 1990-03-01              14.875
# 1990-04-01              14.875
# 1990-05-01              14.875
# 1990-06-01              14.875
# 1990-07-01              14.875

# %% [markdown]
# ### UKHPI Data

# %%
ukhpi_df.head()
# Out:
#          Date       Region_Name  Area_Code     Index
# 0  1968-04-01  Northern Ireland  N92000001  3.300420
# 1  1968-04-01           England  E92000001  1.680067
# 2  1968-04-01             Wales  W92000004  2.119327
# 3  1968-04-01          Scotland  S92000003  2.108087
# 4  1968-04-01            London  E12000007  1.096815

# %%
ukhpi_df['Date'] = pd.to_datetime(ukhpi_df['Date'], format='%Y-%m-%d')
ukhpi_df.drop(columns='Area_Code', inplace=True)

# %%
desired_regions = ['England', 'Wales', 'Northern Ireland', 'Scotland']
national_ukhpi_df = ukhpi_df[ukhpi_df['Region_Name'].isin(desired_regions)]

# %%
national_ukhpi_df = national_ukhpi_df.pivot(index='Date', columns='Region_Name', values='Index')

# %%
national_ukhpi_df['United Kingdom'] = national_ukhpi_df.mean(axis=1)

# %%
national_ukhpi_df.columns = [f'UKHPI {c}' for c in national_ukhpi_df]

# %%
national_ukhpi_df.head()
# Out:
#             UKHPI England  UKHPI Northern Ireland  UKHPI Scotland  \
# Date
# 1968-04-01       1.680067                3.300420        2.108087
# 1968-05-01       1.680067                3.300420        2.108087
# 1968-06-01       1.680067                3.300420        2.108087
# 1968-07-01       1.737342                3.167644        2.311005
# 1968-08-01       1.737342                3.167644        2.311005
#
#             UKHPI Wales  UKHPI United Kingdom
# Date
# 1968-04-01     2.119327              2.301975
# 1968-05-01     2.119327              2.301975
# 1968-06-01     2.119327              2.301975
# 1968-07-01     2.221327              2.359329
# 1968-08-01     2.221327              2.359329

# %% [markdown]
# ### Average Monthly Price Data

# %%
avg_price_df.head()
# Out:
#          Date       Region_Name  Area_Code  Average_Price  Monthly_Change  \
# 0  1968-04-01  Northern Ireland  N92000001    3661.485500             0.0
# 1  1968-04-01           England  E92000001    3408.108064             0.0
# 2  1968-04-01             Wales  W92000004    2885.414162             0.0
# 3  1968-04-01          Scotland  S92000003    2844.980688             0.0
# 4  1968-04-01            London  E12000007    4418.489911             0.0
#
#    Annual_Change  Average_Price_SA
# 0            NaN               NaN
# 1            NaN               NaN
# 2            NaN               NaN
# 3            NaN               NaN
# 4            NaN               NaN

# %%
avg_price_df['Date'] = pd.to_datetime(avg_price_df['Date'], format='%Y-%m-%d')
avg_price_df.drop(columns=['Area_Code', 'Average_Price_SA', 'Monthly_Change', 'Annual_Change'], inplace=True)

# %%
desired_regions = ['England', 'Wales', 'Northern Ireland', 'Scotland']
national_avg_price_df = avg_price_df[avg_price_df['Region_Name'].isin(desired_regions)]

# %%
national_avg_price_df = national_avg_price_df.pivot(index='Date', columns='Region_Name', values='Average_Price')

# %%
national_avg_price_df['United Kingdom'] = national_avg_price_df.mean(axis=1)

# %%
national_avg_price_df.columns = [f'Average Property Price {c}' for c in national_avg_price_df]

# %%
national_avg_price_df.head()
# Out:
#             Average Property Price England  \
# Date
# 1968-04-01                     3408.108064
# 1968-05-01                     3408.108064
# 1968-06-01                     3408.108064
# 1968-07-01                     3524.293566
# 1968-08-01                     3524.293566
#
#             Average Property Price Northern Ireland  \
# Date
# 1968-04-01                              3661.485500
# 1968-05-01                              3661.485500
# 1968-06-01                              3661.485500
# 1968-07-01                              3514.184359
# 1968-08-01                              3514.184359
#
#             Average Property Price Scotland  Average Property Price Wales  \
# Date
# 1968-04-01                      2844.980688                   2885.414162
# 1968-05-01                      2844.980688                   2885.414162
# 1968-06-01                      2844.980688                   2885.414162
# 1968-07-01                      3118.829097                   3024.284362
# 1968-08-01                      3118.829097                   3024.284362
#
#             Average Property Price United Kingdom
# Date
# 1968-04-01                            3199.997103
# 1968-05-01                            3199.997103
# 1968-06-01                            3199.997103
# 1968-07-01                            3295.397846
# 1968-08-01                            3295.397846

# %% [markdown]
# ### Calculate rate of change (CPI/Inflation and UKHPI)

# %%
overall_cpi_df
# Out:
# Aggregate   Housing Associated Costs  Overall Index
# Date
# 1988-01-01                      38.7           46.9
# 1988-02-01                      38.8           47.0
# 1988-03-01                      39.0           47.2
# 1988-04-01                      39.8           47.8
# 1988-05-01                      40.0           48.0
# ...                              ...            ...
# 2023-08-01                     127.8          129.4
# 2023-09-01                     128.3          130.1
# 2023-10-01                     127.9          130.2
# 2023-11-01                     128.2          130.0
# 2023-12-01                     128.6          130.5
#
# [432 rows x 2 columns]

# %%
overall_cpi_df['Housing Associated Costs Inflation Rate'] = overall_cpi_df['Housing Associated Costs'].pct_change()

# %%
overall_cpi_df['Overall Inflation Rate'] = overall_cpi_df['Overall Index'].pct_change()

# %%
overall_cpi_df
# Out:
# Aggregate   Housing Associated Costs  Overall Index  \
# Date
# 1988-01-01                      38.7           46.9
# 1988-02-01                      38.8           47.0
# 1988-03-01                      39.0           47.2
# 1988-04-01                      39.8           47.8
# 1988-05-01                      40.0           48.0
# ...                              ...            ...
# 2023-08-01                     127.8          129.4
# 2023-09-01                     128.3          130.1
# 2023-10-01                     127.9          130.2
# 2023-11-01                     128.2          130.0
# 2023-12-01                     128.6          130.5
#
# Aggregate   Housing Associated Costs Inflation Rate  Overall Inflation Rate
# Date
# 1988-01-01                                      NaN                     NaN
# 1988-02-01                                 0.002584                0.002132
# 1988-03-01                                 0.005155                0.004255
# 1988-04-01                                 0.020513                0.012712
# 1988-05-01                                 0.005025                0.004184
# ...                                             ...                     ...
# 2023-08-01                                 0.003928                0.003101
# 2023-09-01                                 0.003912                0.005410
# 2023-10-01                                -0.003118                0.000769
# 2023-11-01                                 0.002346               -0.001536
# 2023-12-01                                 0.003120                0.003846
#
# [432 rows x 4 columns]

# %%
national_ukhpi_df
# Out:
#             UKHPI England  UKHPI Northern Ireland  UKHPI Scotland  \
# Date
# 1968-04-01       1.680067                3.300420        2.108087
# 1968-05-01       1.680067                3.300420        2.108087
# 1968-06-01       1.680067                3.300420        2.108087
# 1968-07-01       1.737342                3.167644        2.311005
# 1968-08-01       1.737342                3.167644        2.311005
# ...                   ...                     ...             ...
# 2023-07-01     150.300000              161.800000      140.900000
# 2023-08-01     152.000000              161.800000      144.100000
# 2023-09-01     151.700000              161.800000      141.600000
# 2023-10-01     150.400000              161.800000      142.300000
# 2023-11-01     148.700000              161.800000      143.800000
#
#             UKHPI Wales  UKHPI United Kingdom
# Date
# 1968-04-01     2.119327              2.301975
# 1968-05-01     2.119327              2.301975
# 1968-06-01     2.119327              2.301975
# 1968-07-01     2.221327              2.359329
# 1968-08-01     2.221327              2.359329
# ...                 ...                   ...
# 2023-07-01   157.600000            152.650000
# 2023-08-01   158.900000            154.200000
# 2023-09-01   158.200000            153.325000
# 2023-10-01   156.900000            152.850000
# 2023-11-01   156.300000            152.650000
#
# [668 rows x 5 columns]

# %%
for col in national_ukhpi_df:
    national_ukhpi_df[f'{col} % Change'] = national_ukhpi_df[col].pct_change()

# %%
national_ukhpi_df.head()
# Out:
#             UKHPI England  UKHPI Northern Ireland  UKHPI Scotland  \
# Date
# 1968-04-01       1.680067                3.300420        2.108087
# 1968-05-01       1.680067                3.300420        2.108087
# 1968-06-01       1.680067                3.300420        2.108087
# 1968-07-01       1.737342                3.167644        2.311005
# 1968-08-01       1.737342                3.167644        2.311005
#
#             UKHPI Wales  UKHPI United Kingdom  UKHPI England % Change  \
# Date
# 1968-04-01     2.119327              2.301975                     NaN
# 1968-05-01     2.119327              2.301975                0.000000
# 1968-06-01     2.119327              2.301975                0.000000
# 1968-07-01     2.221327              2.359329                0.034091
# 1968-08-01     2.221327              2.359329                0.000000
#
#             UKHPI Northern Ireland % Change  UKHPI Scotland % Change  \
# Date
# 1968-04-01                              NaN                      NaN
# 1968-05-01                          0.00000                 0.000000
# 1968-06-01                          0.00000                 0.000000
# 1968-07-01                         -0.04023                 0.096257
# 1968-08-01                          0.00000                 0.000000
#
#             UKHPI Wales % Change  UKHPI United Kingdom % Change
# Date
# 1968-04-01                   NaN                            NaN
# 1968-05-01              0.000000                       0.000000
# 1968-06-01              0.000000                       0.000000
# 1968-07-01              0.048128                       0.024915
# 1968-08-01              0.000000                       0.000000

# %% [markdown]
# ### Stitch all data into one dataframe

# %%
all_dfs = [overall_cpi_df, monthly_gdp_df, mortgages_df, interest_df, national_ukhpi_df, national_avg_price_df]

# %%
all_dfs_merged = reduce(lambda  left,right: pd.merge(left,right,
                                                     left_index=True, right_index=True,
                                                    how='outer'), all_dfs)

# %%
all_dfs_merged.columns
# Out:
# Index(['Housing Associated Costs', 'Overall Index',
#        'Housing Associated Costs Inflation Rate', 'Overall Inflation Rate',
#        'Monthly GDP', 'Mortgage Approvals', 'Base Interest Rate',
#        'UKHPI England', 'UKHPI Northern Ireland', 'UKHPI Scotland',
#        'UKHPI Wales', 'UKHPI United Kingdom', 'UKHPI England % Change',
#        'UKHPI Northern Ireland % Change', 'UKHPI Scotland % Change',
#        'UKHPI Wales % Change', 'UKHPI United Kingdom % Change',
#        'Average Property Price England',
#        'Average Property Price Northern Ireland',
#        'Average Property Price Scotland', 'Average Property Price Wales',
#        'Average Property Price United Kingdom'],
#       dtype='object')

# %%
all_dfs_merged
# Out:
#             Housing Associated Costs  Overall Index  \
# Date
# 1997-01-01                      63.5           69.2
# 1997-02-01                      63.6           69.3
# 1997-03-01                      63.6           69.4
# 1997-04-01                      64.1           69.7
# 1997-05-01                      64.4           70.0
# ...                              ...            ...
# 2023-07-01                     127.3          129.0
# 2023-08-01                     127.8          129.4
# 2023-09-01                     128.3          130.1
# 2023-10-01                     127.9          130.2
# 2023-11-01                     128.2          130.0
#
#             Housing Associated Costs Inflation Rate  Overall Inflation Rate  \
# Date
# 1997-01-01                                 0.001577               -0.002882
# 1997-02-01                                 0.001575                0.001445
# 1997-03-01                                 0.000000                0.001443
# 1997-04-01                                 0.007862                0.004323
# 1997-05-01                                 0.004680                0.004304
# ...                                             ...                     ...
# 2023-07-01                                -0.013943               -0.003091
# 2023-08-01                                 0.003928                0.003101
# 2023-09-01                                 0.003912                0.005410
# 2023-10-01                                -0.003118                0.000769
# 2023-11-01                                 0.002346               -0.001536
#
#             Monthly GDP  Mortgage Approvals  Base Interest Rate  \
# Date
# 1997-01-01      63.3398             72978.0              5.9375
# 1997-02-01      63.9959             72980.0              5.9375
# 1997-03-01      64.0355             84044.0              5.9375
# 1997-04-01      64.6273            101195.0              5.9375
# 1997-05-01      64.1371            117383.0              5.9375
# ...                 ...                 ...                 ...
# 2023-07-01     102.4073             64958.0              4.6591
# 2023-08-01     102.4166             53023.0              5.0000
# 2023-09-01     102.4730             48063.0              5.2273
# 2023-10-01     102.1730             44293.0              5.2500
# 2023-11-01     102.4924             48927.0              5.2500
#
#             UKHPI England  UKHPI Northern Ireland  UKHPI Scotland  ...  \
# Date                                                               ...
# 1997-01-01      27.501591               46.949854       32.187747  ...
# 1997-02-01      27.704075               46.949854       32.187747  ...
# 1997-03-01      27.992467               46.949854       32.187747  ...
# 1997-04-01      28.383387               44.424597       34.066649  ...
# 1997-05-01      28.837231               44.424597       34.066649  ...
# ...                   ...                     ...             ...  ...
# 2023-07-01     150.300000              161.800000      140.900000  ...
# 2023-08-01     152.000000              161.800000      144.100000  ...
# 2023-09-01     151.700000              161.800000      141.600000  ...
# 2023-10-01     150.400000              161.800000      142.300000  ...
# 2023-11-01     148.700000              161.800000      143.800000  ...
#
#             UKHPI England % Change  UKHPI Northern Ireland % Change  \
# Date
# 1997-01-01                0.000596                         0.039735
# 1997-02-01                0.007363                         0.000000
# 1997-03-01                0.010410                         0.000000
# 1997-04-01                0.013965                        -0.053786
# 1997-05-01                0.015990                         0.000000
# ...                            ...                              ...
# 2023-07-01                0.007373                         0.030573
# 2023-08-01                0.011311                         0.000000
# 2023-09-01               -0.001974                         0.000000
# 2023-10-01               -0.008570                         0.000000
# 2023-11-01               -0.011303                         0.000000
#
#             UKHPI Scotland % Change  UKHPI Wales % Change  \
# Date
# 1997-01-01                -0.018779             -0.008151
# 1997-02-01                 0.000000              0.025432
# 1997-03-01                 0.000000             -0.001807
# 1997-04-01                 0.058373             -0.007601
# 1997-05-01                 0.000000              0.027846
# ...                             ...                   ...
# 2023-07-01                 0.014399              0.016119
# 2023-08-01                 0.022711              0.008249
# 2023-09-01                -0.017349             -0.004405
# 2023-10-01                 0.004944             -0.008217
# 2023-11-01                 0.010541             -0.003824
#
#             UKHPI United Kingdom % Change  Average Property Price England  \
# Date
# 1997-01-01                       0.006769                     55788.50251
# 1997-02-01                       0.007326                     56199.25087
# 1997-03-01                       0.001641                     56784.27139
# 1997-04-01                      -0.003605                     57577.27313
# 1997-05-01                       0.009746                     58497.92049
# ...                                   ...                             ...
# 2023-07-01                       0.017328                    304943.00000
# 2023-08-01                       0.010154                    308325.00000
# 2023-09-01                      -0.005674                    307635.00000
# 2023-10-01                      -0.003098                    305148.00000
# 2023-11-01                      -0.001308                    301613.00000
#
#             Average Property Price Northern Ireland  \
# Date
# 1997-01-01                              52086.16563
# 1997-02-01                              52086.16563
# 1997-03-01                              52086.16563
# 1997-04-01                              49284.64504
# 1997-05-01                              49284.64504
# ...                                             ...
# 2023-07-01                             179530.00000
# 2023-08-01                             179530.00000
# 2023-09-01                             179530.00000
# 2023-10-01                             179530.00000
# 2023-11-01                             179530.00000
#
#             Average Property Price Scotland  Average Property Price Wales  \
# Date
# 1997-01-01                      43439.14962                   43524.95351
# 1997-02-01                      43439.14962                   44631.86395
# 1997-03-01                      43439.14962                   44551.19667
# 1997-04-01                      45974.83204                   44212.55854
# 1997-05-01                      45974.83204                   45443.71838
# ...                                     ...                           ...
# 2023-07-01                     190169.00000                  214635.00000
# 2023-08-01                     194485.00000                  216342.00000
# 2023-09-01                     191123.00000                  215368.00000
# 2023-10-01                     191976.00000                  213573.00000
# 2023-11-01                     194006.00000                  212866.00000
#
#             Average Property Price United Kingdom
# Date
# 1997-01-01                           48709.692817
# 1997-02-01                           49089.107518
# 1997-03-01                           49215.195827
# 1997-04-01                           49262.327187
# 1997-05-01                           49800.278988
# ...                                           ...
# 2023-07-01                          222319.250000
# 2023-08-01                          224670.500000
# 2023-09-01                          223414.000000
# 2023-10-01                          222556.750000
# 2023-11-01                          222003.750000
#
# [323 rows x 22 columns]

# %%
all_dfs_merged.dropna(inplace=True)

# %% [markdown]
# ### Functions to format data for dashboard

# %%
def format_cpi_data(df: pd.DataFrame):
    overall_cpi_df = df[df['Aggregate'].isin(['Overall Index', '04 Housing, water, electricity, gas and other fuels'])]\
        .drop(columns = ['Time', 'uk-only', 'Geography', 'cpih1dim1aggid'])\
        .reset_index(drop=True)
    overall_cpi_df['mmm-yy'] = overall_cpi_df['mmm-yy'].apply(lambda x: datetime.strptime(x, '%b-%y').strftime('%d/%m/%Y'))
    overall_cpi_df['Aggregate'].mask(overall_cpi_df['Aggregate'] == '04 Housing, water, electricity, gas and other fuels',
                                 'Housing Associated Costs', inplace=True)
    overall_cpi_df = overall_cpi_df.rename(columns={'v4_0': 'cpi', 'mmm-yy': 'Date'})
    overall_cpi_df['Date'] = pd.to_datetime(overall_cpi_df['Date'], format='%d/%m/%Y')
    overall_cpi_df = overall_cpi_df.pivot(index='Date', columns='Aggregate', values='cpi')
    overall_cpi_df['Housing Associated Costs Inflation Rate'] = overall_cpi_df['Housing Associated Costs'].pct_change()
    overall_cpi_df['Overall Inflation Rate'] = overall_cpi_df['Overall Index'].pct_change()
    return overall_cpi_df.sort_values('Date')

# %%
format_cpi_data(cpi_df)
# Out:
# Aggregate   Housing Associated Costs  Overall Index  \
# Date
# 1988-01-01                      38.7           46.9
# 1988-02-01                      38.8           47.0
# 1988-03-01                      39.0           47.2
# 1988-04-01                      39.8           47.8
# 1988-05-01                      40.0           48.0
# ...                              ...            ...
# 2023-08-01                     127.8          129.4
# 2023-09-01                     128.3          130.1
# 2023-10-01                     127.9          130.2
# 2023-11-01                     128.2          130.0
# 2023-12-01                     128.6          130.5
#
# Aggregate   Housing Associated Costs Inflation Rate  Overall Inflation Rate
# Date
# 1988-01-01                                      NaN                     NaN
# 1988-02-01                                 0.002584                0.002132
# 1988-03-01                                 0.005155                0.004255
# 1988-04-01                                 0.020513                0.012712
# 1988-05-01                                 0.005025                0.004184
# ...                                             ...                     ...
# 2023-08-01                                 0.003928                0.003101
# 2023-09-01                                 0.003912                0.005410
# 2023-10-01                                -0.003118                0.000769
# 2023-11-01                                 0.002346               -0.001536
# 2023-12-01                                 0.003120                0.003846
#
# [432 rows x 4 columns]

# %%
def format_gdp_data(df: pd.DataFrame):
    monthly_gdp_df = df[df['sic-unofficial'] == 'A--T']\
        .drop(columns = ['Time', 'uk-only', 'Geography', 'sic-unofficial'])\
        .reset_index(drop=True)
    monthly_gdp_df['mmm-yy'] = monthly_gdp_df['mmm-yy'].apply(lambda x: datetime.strptime(x, '%b-%y').strftime('%d/%m/%Y'))
    monthly_gdp_df['UnofficialStandardIndustrialClassification'] = 'Monthly GDP'
    monthly_gdp_df = monthly_gdp_df.rename(columns={'v4_0': 'gdp',
                                                'mmm-yy': 'Date',
                                                'UnofficialStandardIndustrialClassification': 'GDP'})
    monthly_gdp_df['Date'] = pd.to_datetime(monthly_gdp_df['Date'], format='%d/%m/%Y')
    monthly_gdp_df = monthly_gdp_df.pivot(index='Date', columns='GDP', values='gdp')
    return monthly_gdp_df.sort_values('Date')

# %%
format_gdp_data(gdp_df)
# Out:
# GDP         Monthly GDP
# Date
# 1997-01-01      63.3398
# 1997-02-01      63.9959
# 1997-03-01      64.0355
# 1997-04-01      64.6273
# 1997-05-01      64.1371
# ...                 ...
# 2023-07-01     102.4073
# 2023-08-01     102.4166
# 2023-09-01     102.4730
# 2023-10-01     102.1730
# 2023-11-01     102.4924
#
# [323 rows x 1 columns]

# %%
def format_mortgage_data(df: pd.DataFrame):
    mortgages_df = df
    mortgages_df['DATE'] = pd.to_datetime(mortgages_df['DATE'], format='%d %b %Y')  + pd.offsets.MonthBegin(1)
    mortgages_df.rename(columns={
            'DATE': 'Date',
            'LPMVTVU': 'Mortgage Approvals'}, inplace=True)
    mortgages_df.set_index('Date', inplace=True)
    return mortgages_df.sort_values('Date')

# %%
format_mortgage_data(mortgages_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DATE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 format_mortgage_data(mortgages_df)
#
# Cell In[58], line 3, in format_mortgage_data(df)
#       1 def format_mortgage_data(df: pd.DataFrame):
#       2     mortgages_df = df
# ----> 3     mortgages_df['DATE'] = pd.to_datetime(mortgages_df['DATE'], format='%d %b %Y')  + pd.offsets.MonthBegin(1)
#       4     mortgages_df.rename(columns={
#       5             'DATE': 'Date',
#       6             'LPMVTVU': 'Mortgage Approvals'}, inplace=True)
#       7     mortgages_df.set_index('Date', inplace=True)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'DATE'

# %%
def format_interest_data(df: pd.DataFrame):
    interest_df = df
    interest_df['DATE'] = pd.to_datetime(interest_df['DATE'], format='%d %b %Y') + pd.offsets.MonthBegin(1)
    interest_df.rename(columns={
            'DATE': 'Date',
            'IUMABEDR': 'Base Interest Rate'}, inplace=True)
    interest_df.set_index('Date', inplace=True)
    return interest_df.sort_values('Date')

# %%
format_interest_data(interest_df)

# %%
def format_ukhpi_data(df: pd.DataFrame):
    ukhpi_df = df
    ukhpi_df['Date'] = pd.to_datetime(ukhpi_df['Date'], format='%Y-%m-%d')
    ukhpi_df.drop(columns='Area_Code', inplace=True)
    desired_regions = ['England', 'Wales', 'Northern Ireland', 'Scotland']
    national_ukhpi_df = ukhpi_df[ukhpi_df['Region_Name'].isin(desired_regions)]
    national_ukhpi_df = national_ukhpi_df.pivot(index='Date', columns='Region_Name', values='Index')
    national_ukhpi_df['United Kingdom'] = national_ukhpi_df.mean(axis=1)
    national_ukhpi_df.columns = [f'UKHPI {c}' for c in national_ukhpi_df]
    for col in national_ukhpi_df:
        national_ukhpi_df[f'{col} % Change'] = national_ukhpi_df[col].pct_change()
    return national_ukhpi_df.sort_values('Date')

# %%
format_ukhpi_data(ukhpi_df)

# %%
def format_avg_price_data(df: pd.DataFrame):
    avg_price_df = df
    avg_price_df['Date'] = pd.to_datetime(avg_price_df['Date'], format='%Y-%m-%d')
    avg_price_df.drop(columns=['Area_Code', 'Average_Price_SA', 'Monthly_Change', 'Annual_Change'], inplace=True)
    desired_regions = ['England', 'Wales', 'Northern Ireland', 'Scotland']
    national_avg_price_df = avg_price_df[avg_price_df['Region_Name'].isin(desired_regions)]
    national_avg_price_df = national_avg_price_df.pivot(index='Date', columns='Region_Name', values='Average_Price')
    national_avg_price_df['United Kingdom'] = national_avg_price_df.mean(axis=1)
    national_avg_price_df.columns = [f'Average Property Price {c}' for c in national_avg_price_df]
    return national_avg_price_df.sort_values('Date')

# %%
format_avg_price_data(avg_price_df)

# %%
def stitch_all_data(dfs_list: list):
    dfs_merged = reduce(lambda  left,right: pd.merge(left,right,
                                                         left_index=True, right_index=True,
                                                        how='outer'), dfs_list)
    dfs_merged.dropna(inplace=True)
    return dfs_merged

# %%
stitch_all_data(all_dfs)
# Out:
#             Housing Associated Costs  Overall Index  \
# Date
# 1997-01-01                      63.5           69.2
# 1997-02-01                      63.6           69.3
# 1997-03-01                      63.6           69.4
# 1997-04-01                      64.1           69.7
# 1997-05-01                      64.4           70.0
# ...                              ...            ...
# 2023-07-01                     127.3          129.0
# 2023-08-01                     127.8          129.4
# 2023-09-01                     128.3          130.1
# 2023-10-01                     127.9          130.2
# 2023-11-01                     128.2          130.0
#
#             Housing Associated Costs Inflation Rate  Overall Inflation Rate  \
# Date
# 1997-01-01                                 0.001577               -0.002882
# 1997-02-01                                 0.001575                0.001445
# 1997-03-01                                 0.000000                0.001443
# 1997-04-01                                 0.007862                0.004323
# 1997-05-01                                 0.004680                0.004304
# ...                                             ...                     ...
# 2023-07-01                                -0.013943               -0.003091
# 2023-08-01                                 0.003928                0.003101
# 2023-09-01                                 0.003912                0.005410
# 2023-10-01                                -0.003118                0.000769
# 2023-11-01                                 0.002346               -0.001536
#
#             Monthly GDP  Mortgage Approvals  Base Interest Rate  \
# Date
# 1997-01-01      63.3398             72978.0              5.9375
# 1997-02-01      63.9959             72980.0              5.9375
# 1997-03-01      64.0355             84044.0              5.9375
# 1997-04-01      64.6273            101195.0              5.9375
# 1997-05-01      64.1371            117383.0              5.9375
# ...                 ...                 ...                 ...
# 2023-07-01     102.4073             64958.0              4.6591
# 2023-08-01     102.4166             53023.0              5.0000
# 2023-09-01     102.4730             48063.0              5.2273
# 2023-10-01     102.1730             44293.0              5.2500
# 2023-11-01     102.4924             48927.0              5.2500
#
#             UKHPI England  UKHPI Northern Ireland  UKHPI Scotland  ...  \
# Date                                                               ...
# 1997-01-01      27.501591               46.949854       32.187747  ...
# 1997-02-01      27.704075               46.949854       32.187747  ...
# 1997-03-01      27.992467               46.949854       32.187747  ...
# 1997-04-01      28.383387               44.424597       34.066649  ...
# 1997-05-01      28.837231               44.424597       34.066649  ...
# ...                   ...                     ...             ...  ...
# 2023-07-01     150.300000              161.800000      140.900000  ...
# 2023-08-01     152.000000              161.800000      144.100000  ...
# 2023-09-01     151.700000              161.800000      141.600000  ...
# 2023-10-01     150.400000              161.800000      142.300000  ...
# 2023-11-01     148.700000              161.800000      143.800000  ...
#
#             UKHPI England % Change  UKHPI Northern Ireland % Change  \
# Date
# 1997-01-01                0.000596                         0.039735
# 1997-02-01                0.007363                         0.000000
# 1997-03-01                0.010410                         0.000000
# 1997-04-01                0.013965                        -0.053786
# 1997-05-01                0.015990                         0.000000
# ...                            ...                              ...
# 2023-07-01                0.007373                         0.030573
# 2023-08-01                0.011311                         0.000000
# 2023-09-01               -0.001974                         0.000000
# 2023-10-01               -0.008570                         0.000000
# 2023-11-01               -0.011303                         0.000000
#
#             UKHPI Scotland % Change  UKHPI Wales % Change  \
# Date
# 1997-01-01                -0.018779             -0.008151
# 1997-02-01                 0.000000              0.025432
# 1997-03-01                 0.000000             -0.001807
# 1997-04-01                 0.058373             -0.007601
# 1997-05-01                 0.000000              0.027846
# ...                             ...                   ...
# 2023-07-01                 0.014399              0.016119
# 2023-08-01                 0.022711              0.008249
# 2023-09-01                -0.017349             -0.004405
# 2023-10-01                 0.004944             -0.008217
# 2023-11-01                 0.010541             -0.003824
#
#             UKHPI United Kingdom % Change  Average Property Price England  \
# Date
# 1997-01-01                       0.006769                     55788.50251
# 1997-02-01                       0.007326                     56199.25087
# 1997-03-01                       0.001641                     56784.27139
# 1997-04-01                      -0.003605                     57577.27313
# 1997-05-01                       0.009746                     58497.92049
# ...                                   ...                             ...
# 2023-07-01                       0.017328                    304943.00000
# 2023-08-01                       0.010154                    308325.00000
# 2023-09-01                      -0.005674                    307635.00000
# 2023-10-01                      -0.003098                    305148.00000
# 2023-11-01                      -0.001308                    301613.00000
#
#             Average Property Price Northern Ireland  \
# Date
# 1997-01-01                              52086.16563
# 1997-02-01                              52086.16563
# 1997-03-01                              52086.16563
# 1997-04-01                              49284.64504
# 1997-05-01                              49284.64504
# ...                                             ...
# 2023-07-01                             179530.00000
# 2023-08-01                             179530.00000
# 2023-09-01                             179530.00000
# 2023-10-01                             179530.00000
# 2023-11-01                             179530.00000
#
#             Average Property Price Scotland  Average Property Price Wales  \
# Date
# 1997-01-01                      43439.14962                   43524.95351
# 1997-02-01                      43439.14962                   44631.86395
# 1997-03-01                      43439.14962                   44551.19667
# 1997-04-01                      45974.83204                   44212.55854
# 1997-05-01                      45974.83204                   45443.71838
# ...                                     ...                           ...
# 2023-07-01                     190169.00000                  214635.00000
# 2023-08-01                     194485.00000                  216342.00000
# 2023-09-01                     191123.00000                  215368.00000
# 2023-10-01                     191976.00000                  213573.00000
# 2023-11-01                     194006.00000                  212866.00000
#
#             Average Property Price United Kingdom
# Date
# 1997-01-01                           48709.692817
# 1997-02-01                           49089.107518
# 1997-03-01                           49215.195827
# 1997-04-01                           49262.327187
# 1997-05-01                           49800.278988
# ...                                           ...
# 2023-07-01                          222319.250000
# 2023-08-01                          224670.500000
# 2023-09-01                          223414.000000
# 2023-10-01                          222556.750000
# 2023-11-01                          222003.750000
#
# [323 rows x 22 columns]
